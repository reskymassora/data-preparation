# %%
#Import Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import Dataframe
movies_data = pd.read_csv('movies_metadata.csv', sep=',')

# %%
# Melihat informasi dalam data seperti kolom dan tipe data
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45463 non-null  bool
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45463 non-null  int64
#  3   genres                 45463 non-null  object
#  4   homepage               7779 non-null   object
#  5   id                     45463 non-null  int64
#  6   imdb_id                45446 non-null  object
#  7   original_language      45452 non-null  object
#  8   original_title         45463 non-null  object
#  9   overview               44509 non-null  object
#  10  popularity             45460 non-null  float64
#  11  poster_path            45077 non-null  object
#  12  production_companies   45460 non-null  object
#  13  production_countries   45460 non-null  object
# ...

# %%
# Menampilkan data
movies_data
# Out:
#        adult                              belongs_to_collection    budget  \
# 0       True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1       True                                                NaN  65000000
# 2       True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3       True                                                NaN  16000000
# 4       True  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45458   True                                                NaN         0
# 45459   True                                                NaN         0
# 45460   True                                                NaN         0
# 45461   True                                                NaN         0
# 45462   True                                                NaN         0
#
#                                                   genres  \
# ...

# %%
# Menampilkan 10 data teratas
movies_data.head(10)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0   True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   True                                                NaN  65000000
# 2   True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   True                                                NaN  16000000
# 4   True  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5   True                                                NaN  60000000
# 6   True                                                NaN  58000000
# 7   True                                                NaN         0
# 8   True                                                NaN  35000000
# 9   True  {'id': 645, 'name': 'James Bond Collection', '...  58000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %%
# Menampilkan 5 data terakhir
movies_data.tail()
# Out:
#        adult belongs_to_collection  budget  \
# 45458   True                   NaN       0
# 45459   True                   NaN       0
# 45460   True                   NaN       0
# 45461   True                   NaN       0
# 45462   True                   NaN       0
#
#                                                   genres  \
# 45458  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45459                      [{'id': 18, 'name': 'Drama'}]
# 45460  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45461                                                 []
# 45462                                                 []
#
#                                    homepage      id    imdb_id  \
# 45458  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45459                                   NaN  111109  tt2028550
# 45460                                   NaN   67758  tt0303758
# 45461                                   NaN  227506  tt0008536
# ...

# %%
# Menampilkan data secara acak 
movies_data.sample(5)
# Out:
#        adult belongs_to_collection  budget  \
# 5567    True                   NaN  150000
# 27572   True                   NaN       0
# 15981   True                   NaN       0
# 36823   True                   NaN       0
# 16772   True                   NaN       0
#
#                                                   genres  \
# 5567   [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 27572  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 15981  [{'id': 10402, 'name': 'Music'}, {'id': 10749,...
# 36823                [{'id': 99, 'name': 'Documentary'}]
# 16772  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
#
#                                                 homepage      id    imdb_id  \
# 5567                                                 NaN   44932  tt0081764
# 27572  http://www.puzzypower.dk/UK/index.php/all-abou...   16048  tt0349080
# 15981                                                NaN   52848  tt0043123
# ...

# %%
# Melihat index dalam data
movies_data.index
# Out:
# RangeIndex(start=0, stop=45463, step=1)

# %%
# Menjadikan kolom 'original_title' sebagai index atau primary key
movies_data.set_index('original_title')
# Out:
#                              adult  \
# original_title
# Toy Story                     True
# Jumanji                       True
# Grumpier Old Men              True
# Waiting to Exhale             True
# Father of the Bride Part II   True
# ...                            ...
# رگ خواب                       True
# Siglo ng Pagluluwal           True
# Betrayal                      True
# Satana likuyushchiy           True
# Queerama                      True
#
#                                                          belongs_to_collection  \
# original_title
# Toy Story                    {'id': 10194, 'name': 'Toy Story Collection', ...
# Jumanji                                                                    NaN
# Grumpier Old Men             {'id': 119050, 'name': 'Grumpy Old Men Collect...
# Waiting to Exhale                                                          NaN
# Father of the Bride Part II  {'id': 96871, 'name': 'Father of the Bride Col...
# ...

# %%
# Konversi release date menjadi tipe data datetime
movies_data["release_date"] = pd.to_datetime(movies_data["release_date"], errors='coerce')

# %%
# Melihat apakah berhasil atau tidak
movies_data["release_date"].info
# Out:
# <bound method Series.info of 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
#            ...
# 45458          NaT
# 45459   2011-11-17
# 45460   2003-08-01
# 45461   1917-10-21
# 45462   2017-06-09
# Name: release_date, Length: 45463, dtype: datetime64[ns]>

# %%
# Menampilkan film yang sudah release
movies_data["status"] == "Released"
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 45458    True
# 45459    True
# 45460    True
# 45461    True
# 45462    True
# Name: status, Length: 45463, dtype: bool

# %%
# Menampilkan film dengan budget yang paling mahal 
movies_data.sort_values("budget", ascending = False).head(10)
# Out:
#        adult                              belongs_to_collection     budget  \
# 17124   True  {'id': 295, 'name': 'Pirates of the Caribbean ...  380000000
# 11827   True  {'id': 295, 'name': 'Pirates of the Caribbean ...  300000000
# 26557   True  {'id': 86311, 'name': 'The Avengers Collection...  280000000
# 11067   True  {'id': 8537, 'name': 'Superman Collection', 'p...  270000000
# 16130   True  {'id': 463959, 'name': 'Tangled Collection', '...  260000000
# 18685   True                                                NaN  260000000
# 44839   True  {'id': 8650, 'name': 'Transformers Collection'...  260000000
# 11780   True  {'id': 556, 'name': 'Spider-Man Collection', '...  258000000
# 21174   True                                                NaN  255000000
# 19970   True  {'id': 121938, 'name': 'The Hobbit Collection'...  250000000
#
#                                                   genres  \
# 17124  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# ...

# %%
# Menampilkan film dengan budget dan pendapatan yang paling murah
movies_data.sort_values(["budget", "revenue"], ascending = [True, True]).head(10)
# Out:
#     adult                              belongs_to_collection  budget  \
# 2    True  {'id': 119050, 'name': 'Grumpy Old Men Collect...       0
# 7    True                                                NaN       0
# 11   True                                                NaN       0
# 21   True                                                NaN       0
# 23   True                                                NaN       0
# 25   True                                                NaN       0
# 27   True                                                NaN       0
# 29   True                                                NaN       0
# 32   True                                                NaN       0
# 34   True                                                NaN       0
#
#                                                genres homepage     id  \
# 2   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...      NaN  15602
# ...

# %%
# Cek duplikasi
movies_data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45458    False
# 45459    False
# 45460    False
# 45461    False
# 45462    False
# Length: 45463, dtype: bool

# %%
# Cek jumlah data yang terduplikat
movies_data.duplicated().sum()
# Out:
# 17

# %%
# Melihat data mana saja yang duplikat
movies_data[movies_data.duplicated()]
# Out:
#        adult                              belongs_to_collection  budget  \
# 1465    True                                                NaN       0
# 9165    True                                                NaN       0
# 9327    True                                                NaN       0
# 13375   True                                                NaN       0
# 16764   True                                                NaN       0
# 21164   True                                                NaN       0
# 21853   True                                                NaN       0
# 22150   True                                                NaN       0
# 23043   True                                                NaN       0
# 24843   True                                                NaN       0
# 28859   True                                                NaN       0
# 29373   True                                                NaN       0
# ...

# %%
# Melihat jumlah data mana saja yang duplikat dari segi judul 
movies_data[movies_data.duplicated(subset = ["original_title"])]
# Out:
#        adult belongs_to_collection   budget  \
# 888     True                   NaN  2238813
# 930     True                   NaN        0
# 1296    True                   NaN        0
# 1465    True                   NaN        0
# 1832    True                   NaN   750000
# ...      ...                   ...      ...
# 45412   True                   NaN        0
# 45417   True                   NaN        0
# 45451   True                   NaN        0
# 45457   True                   NaN        0
# 45460   True                   NaN        0
#
#                                                   genres homepage      id  \
# 888    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN    6620
# 930                        [{'id': 18, 'name': 'Drama'}]      NaN   85638
# 1296   [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      NaN   11349
# 1465   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN  105045
# ...

# %%
# Melihat jumlah data mana saja yang duplikat dari segi judul 
movies_data[movies_data.duplicated(subset = ["original_title"], keep = False)].sort_values("original_title", ascending=True)
# Out:
#        adult                              belongs_to_collection   budget  \
# 1161    True                                                NaN   350000
# 15200   True                                                NaN        0
# 990     True                                                NaN  5000000
# 20847   True                                                NaN        0
# 13003   True                                                NaN   200000
# ...      ...                                                ...      ...
# 36039   True                                                NaN        0
# 25045   True                                                NaN        0
# 8927    True                                                NaN  6900000
# 17169   True  {'id': 303969, 'name': 'Martin Scorsese’s Worl...        0
# 16568   True                                                NaN  4000000
#
#                                                   genres  \
# ...

# %%
# Menghapus data yang duplicate
#1. movies_data = movies_data.drop_duplicates()
movies_data.drop_duplicates(inplace = True)

# %%
movies_data
# Out:
#        adult                              belongs_to_collection    budget  \
# 0       True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1       True                                                NaN  65000000
# 2       True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3       True                                                NaN  16000000
# 4       True  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45458   True                                                NaN         0
# 45459   True                                                NaN         0
# 45460   True                                                NaN         0
# 45461   True                                                NaN         0
# 45462   True                                                NaN         0
#
#                                                   genres  \
# ...

# %%
# Mengecek apakah masih ada data yang duplicate
movies_data.duplicated().sum()
# Out:
# 0

# %%
# Mengecek jumlah data yang missing atau hilang
movies_data.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40956
# budget                       0
# genres                       0
# homepage                 37669
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   3
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      3
# runtime                    260
# spoken_languages             3
# status                      84
# tagline                  25039
# title                        3
# video                        0
# vote_average                 3
# vote_count                   3
# dtype: int64

# %%
# Mengisi colomg belongs to collection yang kosong 
movies_data["belongs_to_collection"] = movies_data["belongs_to_collection"].fillna("No Belongs To Collection")

# %%
# Mengecek apakah ada data yang masih kosong pada kolom belongs to collection
movies_data["belongs_to_collection"].isna().sum()
# Out:
# 0

# %%
# Mengisi colom homepage yang kosong 
movies_data["homepage"] = movies_data["homepage"].fillna("No homepage")

# %%
# Mengecek apakah ada data yang masih kosong pada kolom belongs to collection
movies_data["homepage"].isna().sum()
# Out:
# 0

# %%
# Mengisi colom tagline yang kosong 
movies_data["tagline"] = movies_data["tagline"].fillna("No tagline")

# %%
# Mengecek apakah ada data yang masih kosong pada kolom belongs to collection
movies_data["homepage"].isna().sum()
# Out:
# 0

# %%
# Mengisi colom overview yang kosong 
movies_data["overview"] = movies_data["overview"].fillna("No overview")

# %%
# Mengecek apakah ada data yang masih kosong pada kolom belongs to collection
movies_data["homepage"].isna().sum()
# Out:
# 0

# %%
# Mengecek jumlah data yang missing atau hilang
movies_data.isna().sum()
# Out:
# adult                      0
# belongs_to_collection      0
# budget                     0
# genres                     0
# homepage                   0
# id                         0
# imdb_id                   17
# original_language         11
# original_title             0
# overview                   0
# popularity                 3
# poster_path              386
# production_companies       3
# production_countries       3
# release_date              87
# revenue                    3
# runtime                  260
# spoken_languages           3
# status                    84
# tagline                    0
# title                      3
# video                      0
# vote_average               3
# vote_count                 3
# dtype: int64

# %%
# Mengisi colom poster_path yang kosong 
movies_data["poster_path"] = movies_data["poster_path"].fillna("No poster_path")

# %%
# Mengisi colom runtime yang kosong 
movies_data["runtime"] = movies_data["runtime"].fillna("No runtiime")

# %%
# Mengecek jumlah data yang missing atau hilang
movies_data.isna().sum()
# Out:
# adult                     0
# belongs_to_collection     0
# budget                    0
# genres                    0
# homepage                  0
# id                        0
# imdb_id                  17
# original_language        11
# original_title            0
# overview                  0
# popularity                3
# poster_path               0
# production_companies      3
# production_countries      3
# release_date             87
# revenue                   3
# runtime                   0
# spoken_languages          3
# status                   84
# tagline                   0
# title                     3
# video                     0
# vote_average              3
# vote_count                3
# dtype: int64

# %%
movies_data.isna().sum()
# Out:
# adult                     0
# belongs_to_collection     0
# budget                    0
# genres                    0
# homepage                  0
# id                        0
# imdb_id                  17
# original_language        11
# original_title            0
# overview                  0
# popularity                3
# poster_path               0
# production_companies      3
# production_countries      3
# release_date             87
# revenue                   3
# runtime                   0
# spoken_languages          3
# status                   84
# tagline                   0
# title                     3
# video                     0
# vote_average              3
# vote_count                3
# dtype: int64

# %%
# Menghapus baris yang kolom release date nya kosong
moviies_data = movies_data.dropna(subset=["release_date"])

# %%
movies_data = moviies_data

# %%
movies_data.isna().sum()
# Out:
# adult                     0
# belongs_to_collection     0
# budget                    0
# genres                    0
# homepage                  0
# id                        0
# imdb_id                  14
# original_language        11
# original_title            0
# overview                  0
# popularity                0
# poster_path               0
# production_companies      0
# production_countries      0
# release_date              0
# revenue                   0
# runtime                   0
# spoken_languages          0
# status                   80
# tagline                   0
# title                     0
# video                     0
# vote_average              0
# vote_count                0
# dtype: int64

# %%
# Menghapus data dengan banyak argumen
movies_data = movies_data.dropna(subset=["imdb_id", "original_language", "spoken_languages", "status"])

# %%
movies_data.isna().sum()
# Out:
# adult                    0
# belongs_to_collection    0
# budget                   0
# genres                   0
# homepage                 0
# id                       0
# imdb_id                  0
# original_language        0
# original_title           0
# overview                 0
# popularity               0
# poster_path              0
# production_companies     0
# production_countries     0
# release_date             0
# revenue                  0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                  0
# title                    0
# video                    0
# vote_average             0
# vote_count               0
# dtype: int64

# %%
movies_data.describe()
# Out:
#              budget             id    popularity  \
# count  4.525400e+04   45254.000000  45254.000000
# mean   4.243908e+06  108048.125779      2.932561
# min    0.000000e+00       2.000000      0.000000
# 25%    0.000000e+00   26340.500000      0.391880
# 50%    0.000000e+00   59824.000000      1.133516
# 75%    0.000000e+00  156932.000000      3.706840
# max    3.800000e+08  469172.000000    547.488298
# std    1.746199e+07  112228.390980      6.015930
#
#                         release_date       revenue  vote_average    vote_count
# count                          45254  4.525400e+04  45254.000000  45254.000000
# mean   1992-05-12 06:24:25.329031680  1.126033e+07      5.627953    110.367526
# min              1874-12-09 00:00:00  0.000000e+00      0.000000      0.000000
# 25%              1978-09-29 00:00:00  0.000000e+00      5.000000      3.000000
# 50%              2001-08-24 00:00:00  0.000000e+00      6.000000     10.000000
# ...

# %%
movies_data.sample(10)
# Out:
#        adult     belongs_to_collection    budget  \
# 4041    True  No Belongs To Collection  60000000
# 19634   True  No Belongs To Collection         0
# 7341    True  No Belongs To Collection         0
# 13549   True  No Belongs To Collection         0
# 41638   True  No Belongs To Collection         0
# 44538   True  No Belongs To Collection         0
# 12363   True  No Belongs To Collection         0
# 44196   True  No Belongs To Collection         0
# 38033   True  No Belongs To Collection         0
# 27180   True  No Belongs To Collection         0
#
#                                                   genres  \
# 4041   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 19634                [{'id': 99, 'name': 'Documentary'}]
# 7341   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 13549  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 41638  [{'id': 10752, 'name': 'War'}, {'id': 18, 'nam...
# 44538                     [{'id': 35, 'name': 'Comedy'}]
# ...
